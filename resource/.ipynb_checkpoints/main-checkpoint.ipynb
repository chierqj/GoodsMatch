# %%
import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

# seller_name = ["seller_id", "breed", "good_id", "good_stock",
#                "depot_id", "brand", "place", "year", "level", "category"]
# buyer_name = ["buyer_id", "hold_time", "buy_count", "breed", "expect1", "value1",
#               "expect2", "value2", "expect3", "value3", "expect4", "value4", "expect5", "value5"]

df_seller = pd.read_csv("./seller.txt", header=0, low_memory=False, dtype=np.str)
df_buyer = pd.read_csv("./buyer.txt", header=0, low_memory=False, dtype=np.str)
df_seller.fillna(value='null', inplace=True)
df_buyer.fillna(value='null', inplace=True)
df_seller[['货物数量（张）']] = df_seller[['货物数量（张）']].values.astype(int)
df_buyer[['平均持仓时间', '购买货物数量']] = df_buyer[['平均持仓时间', '购买货物数量']].values.astype(int)

# %%
df_seller.head()
# Out:
#            卖方客户  品种             货物编号 货物数量（张）   仓库    品牌   产地    年度     等级  \
# 0  999900000001  CF  CF2020011104087       8  314  null   新疆  2020  1230A
# 1  999900000001  CF  CF2020011103822       1  335  null   新疆  2020  1228C
# 2  999900000002  CF  CF2020011108737       2  309  null  非新疆  2020  2228A
# 3  999900000002  CF  CF2020011101610       6  325  null   新疆  2020  4128C
# 4  999900000002  CF  CF2020011104593       2  332  null   新疆  2020  4128C
#
#        类别
# 0  S1U2P3
# 1  S2U3P2
# 2  S2U3P2
# 3  S3U2P3
# 4  S1U3P2

# %%
depot = df_seller[df_seller["仓库"]=="311"]
depot_gr = depot.groupby(["品种", "货物编号"]).
# Out:
#                 卖方客户  品种             货物编号 货物数量（张）   仓库    品牌   产地    年度  \
# 26      999900000006  CF  CF2020011109847       4  311  null   新疆  2020
# 29      999900000007  CF  CF2020011107750       6  311  null  非新疆  2020
# 33      999900000009  CF  CF2020011104323       9  311  null   新疆  2020
# 45      999900000011  CF  CF2020011105423       3  311  null  非新疆  2020
# 80      999900000019  CF  CF2020011105185       4  311  null  非新疆  1920
# ...              ...  ..              ...     ...  ...   ...  ...   ...
# 190394  999900038008  CF  CF2020011109892       4  311  null  非新疆  2020
# 190460  999900038021  CF  CF2020011102573       5  311  null  非新疆  2020
# 200046  999900039933  CF  CF2020011101725       6  311  null   新疆  1920
# 206370  999900041189  CF  CF2020011109892       7  311  null  非新疆  2020
# 213821  999900042661  CF  CF2020011109892       6  311  null  非新疆  2020
#
#            等级      类别
# 26      2227B  S4U4P2
# 29      1227A  S3U4P2
# 33      1128C  S4U4P2
# 45      4131A  S2U4P2
# 80      1130A  S2U2P1
# ...       ...     ...
# 190394  2128C  S2U4P2
# 190460  4130B  S2U2P3
# 200046  1130A  S3U3P1
# 206370  2128C  S2U4P2
# 213821  2128C  S2U4P2
#
# [3600 rows x 10 columns]

# %%
df_buyer.head()
# Out:
#            买方客户 平均持仓时间 购买货物数量  品种 第一意向    值 第二意向     值.1 第三意向    值.2 第四意向  \
# 0  999800000000   3390     40  CF   仓库  314   产地      新疆   等级  4131B   类别
# 1  999800000001   4952      5  CF   仓库  325   年度    2020   产地     新疆   类别
# 2  999800000002   3711     24  CF   仓库  301   产地      新疆   等级  4128A   类别
# 3  999800000003   4100     56  CF   仓库  304   年度    1920   产地     新疆   类别
# 4  999800000004    237     57  CF   仓库  301   类别  S2U3P2   产地     新疆   等级
#
#       值.3  第五意向    值.4
# 0  S3U3P3  null   null
# 1  S3U4P2    等级  1130A
# 2  S3U3P3    年度   1920
# 3  S3U3P2  null   null
# 4   2128C    年度   1920

# %%
df_buyer_gr = df_buyer.groupby(
    ['第一意向', '值', '第二意向', '值.1', '第三意向', '值.2', '第四意向', '值.3', '第五意向', '值.4']).count()
# df_buyer_gr.shape
df_buyer.shape
# Out:
# (100000, 14)

# %%
df_seller_gr = df_seller.groupby(["品种", "仓库"]).agg({'货物数量（张）': {'sum', 'count'}})
print("shape: ", df_seller_gr.shape)
df_seller_gr
# Out:
# shape:  (43, 2)
#        货物数量（张）
#            sum  count
# 品种 仓库
# CF 301   63695  12722
#    302   67286  13529
#    303   65267  13084
#    304   62612  12539
#    305   62392  12507
#    306   64718  12924
#    307   63653  12688
#    308   66946  13413
#    309   69366  13833
#    310   66874  13304
#    311   72762  14528
#    313   62323  12417
#    314   67194  13490
#    317   66246  13341
#    319   72480  14472
#    320   72752  14502
#    322   62418  12465
#    323   71786  14378
#    324   66979  13381
#    325   67030  13366
#    326   70873  14152
#    327   61125  12205
#    328   68153  13527
#    329   63032  12706
#    330   70223  13955
#    331   64605  12979
#    332   66425  13390
#    333   68603  13650
#    334   61844  12381
#    335   70338  14009
# SR 112  241155   2412
#    409  235380   2323
#    417  235411   2358
#    428  220534   2194
#    435  231887   2304
#    437  249409   2452
#    438  234793   2346
#    441  229903   2293
#    445  212022   2098
#    449  222794   2210
#    450  218586   2218
#    452  237874   2378
#    508  230252   2256

# %%
df_buyer_gr = df_buyer.groupby(["品种", "第一意向", "值"])

for it in df_buyer_gr:
    df = it[1]
    df = df.sort_values(by='平均持仓时间', ascending=False)
    data = df[["平均持仓时间", "购买货物数量"]].head(100)
    data = data.rename(columns={'平均持仓时间': 'hold_time', '购买货物数量': 'buy_count'})
    
    plt.figure(figsize=(100, 100))
    data.plot(x="hold_time", y="buy_count", kind="scatter")
    plt.show()
    
    break

# %%
df_buyer_gr = df_buyer.groupby(["品种", "第一意向", "值"]).agg({'购买货物数量': {'sum', 'count'}})
df_buyer_gr.columns.get_level_values(1)
df_buyer_gr.columns = df_buyer_gr.columns.droplevel(0)
df_buyer_gr.head(50)
# Out:
#                   sum  count
# 品种 第一意向 值
# CF null null    33969    849
#    产地   新疆     728055  18045
#         非新疆     64241   1619
#    仓库   301    103041   2544
#         302      9407    264
#         303     10147    251
#         304    106326   2679
#         306      9141    226
#         307      9010    234
#         308      8265    204
#         309      9581    237
#         311    104093   2612
#         313    103663   2581
#         314      8434    218
#         319      9092    235
#         320     10640    256
#         322     10649    269
#         324    103358   2644
#         325    104273   2596
#         326      9263    240
#         328      9041    233
#         329     11184    269
#         330      8706    235
#         331     10475    249
#         332      8070    213
#         335      9470    251
#    年度   1920    64175   1604
#         2020    66750   1657
#    等级   1127B    2451     50
#         1127C    1698     45
#         1128A    1906     42
#         1128B    1927     44
#         1128C    1967     44
#         1129A    1742     46
#         1129B    1154     36
#         1129C    1514     39
#         1130A    1689     38
#         1130B    1799     54
#         1130C    2164     47
#         1131B    2908     57
#         1227A    1500     42
#         1227B    2398     59
#         1227C    2306     47
#         1228A    1639     42
#         1228B    1847     44
#         1228C    2258     56
#         1229A    1748     54
#         1229B    1678     47
#         1229C    1777     46
#         1230A    1794     45

# %%
# df_seller_gr = df_seller.groupby(["货物编号"]).agg({'货物数量（张）': {'sum', 'count', 'max', 'min'}})
df_seller_gr = df_seller.groupby(["货物编号"]).count()
df_seller_gr1 = df_seller.groupby(['仓库'])


for it in df_seller_gr1:
    data = it[1].groupby(["货物编号"], as_index=False).agg(
        {'货物数量（张）': {'sum', 'count', 'max', 'min'}})

    data = data.rename(columns={'货物编号': 'good_id', '货物数量（张）': 'good_stock'})

    fig = plt.figure(figsize=(18, 10))

    print("仓库: ", it[0], "货物种类: ", data.shape[0])
    plt.subplot(221)
    plt.scatter(data.index.get_level_values(0).values,
                data[('good_stock', 'count')], label='count')
    plt.legend()

    plt.subplot(222)
    plt.scatter(data.index.get_level_values(0).values,
                data[('good_stock', 'sum')], label='sum')
    plt.legend()

    plt.subplot(223)
    plt.scatter(data.index.get_level_values(0).values,
                data[('good_stock', 'max')], label='max')
    plt.legend()

    plt.subplot(224)
    plt.scatter(data.index.get_level_values(0).values,
                data[('good_stock', 'min')], label='min')
    plt.legend()
    plt.show()
# Out:
# 仓库:  112 货物种类:  750
# 仓库:  301 货物种类:  320
# 仓库:  302 货物种类:  342
# 仓库:  303 货物种类:  330
# 仓库:  304 货物种类:  313
# 仓库:  305 货物种类:  316
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-40ce0d938753> in <module>
#      28     plt.legend()
#      29
# ---> 30     plt.subplot(224)
#      31     plt.scatter(data.index.get_level_values(0).values,
#      32                 data[('good_stock', 'min')], label='min')
#
# ~/Library/Python/3.7/lib/python/site-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1140
#    1141     fig = gcf()
# -> 1142     ax = fig.add_subplot(*args, **kwargs)
#    1143     bbox = ax.bbox
#    1144     axes_to_delete = []
#
# ~/Library/Python/3.7/lib/python/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1400                     # more similar to add_axes.
#    1401                     self._axstack.remove(ax)
# -> 1402             ax = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1403
#    1404         return self._add_axes_internal(key, ax)
#
# ~/Library/Python/3.7/lib/python/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      40         self.update_params()
#      41         # _axes_class is set in the subplot_class_factory
# ---> 42         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      43         # add a layout box to this, for both the full axis, and the poss
#      44         # of the axis.  We need both because the axes may become smaller
#
# ~/Library/Python/3.7/lib/python/site-packages/matplotlib/axes/_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, **kwargs)
#     509
#     510         self._rasterization_zorder = None
# --> 511         self.cla()
#     512
#     513         # funcs used to format x and y - fall back on major formatters
#
# ~/Library/Python/3.7/lib/python/site-packages/matplotlib/axes/_base.py in cla(self)
#    1159         self.set_axis_on()
#    1160
# -> 1161         self.xaxis.set_clip_path(self.patch)
#    1162         self.yaxis.set_clip_path(self.patch)
#    1163
#
# ~/Library/Python/3.7/lib/python/site-packages/matplotlib/axis.py in set_clip_path(self, clippath, transform)
#     899     def set_clip_path(self, clippath, transform=None):
#     900         martist.Artist.set_clip_path(self, clippath, transform)
# --> 901         for child in self.majorTicks + self.minorTicks:
#     902             child.set_clip_path(clippath, transform)
#     903         self.stale = True
#
# ~/Library/Python/3.7/lib/python/site-packages/matplotlib/axis.py in __get__(self, instance, cls)
#     621             else:
#     622                 instance.minorTicks = []
# --> 623                 tick = instance._get_tick(major=False)
#     624                 instance.minorTicks.append(tick)
#     625                 return instance.minorTicks
#
# ~/Library/Python/3.7/lib/python/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    2011         else:
#    2012             tick_kw = self._minor_tick_kw
# -> 2013         return XTick(self.axes, 0, major=major, **tick_kw)
#    2014
#    2015     def set_label_position(self, position):
#
# ~/Library/Python/3.7/lib/python/site-packages/matplotlib/axis.py in __init__(self, *args, **kwargs)
#     420             xdata=[0], ydata=[0],
#     421             transform=self.axes.get_xaxis_transform(which="tick1"),
# --> 422             marker=self._tickmarkers[0],
#     423         )
#     424         self.tick2line.set(
#
# ~/Library/Python/3.7/lib/python/site-packages/matplotlib/artist.py in set(self, **kwargs)
#    1086     def set(self, **kwargs):
#    1087         """A property batch setter.  Pass *kwargs* to set properties."""
# -> 1088         kwargs = cbook.normalize_kwargs(kwargs, self)
#    1089         move_color_to_start = False
#    1090         if "color" in kwargs:
#
# ~/Library/Python/3.7/lib/python/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     384     @functools.wraps(func)
#     385     def wrapper(*inner_args, **inner_kwargs):
# --> 386         arguments = signature.bind(*inner_args, **inner_kwargs).arguments
#     387         if is_varargs and arguments.get(name):
#     388             warn_deprecated(
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/inspect.py in bind(*args, **kwargs)
#    3013         if the passed arguments can not be bound.
#    3014         """
# -> 3015         return args[0]._bind(args[1:], kwargs)
#    3016
#    3017     def bind_partial(*args, **kwargs):
#
# KeyboardInterrupt:
